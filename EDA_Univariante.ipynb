# %%
import pandas as pd

# %%
df=pd.read_csv('./data/train_and_test2.csv')
df.columns
df=df[['Passengerid','Age','Fare','Sex','sibsp','Parch','Pclass','Embarked','2urvived']]
df.sample(10)
# Out:
#       Passengerid   Age     Fare  Sex  sibsp  Parch  Pclass  Embarked  \
# 643           644  28.0  56.4958    0      0      0       3       2.0
# 229           230  28.0  25.4667    1      3      1       3       2.0
# 1118         1119  28.0   7.7500    1      0      0       3       1.0
# 1222         1223  39.0  29.7000    0      0      0       1       0.0
# 1090         1091  28.0   8.1125    1      0      0       3       2.0
# 292           293  36.0  12.8750    0      0      0       2       0.0
# 517           518  28.0  24.1500    0      0      0       3       1.0
# 1161         1162  46.0  75.2417    0      0      0       1       0.0
# 540           541  36.0  71.0000    1      0      2       1       2.0
# 824           825   2.0  39.6875    0      4      1       3       2.0
#
#       2urvived
# 643          1
# 229          0
# 1118         0
# 1222         0
# 1090         0
# 292          0
# 517          0
# 1161         0
# 540          1
# 824          0

# %%
df.describe()
# Out:
#        Passengerid          Age         Fare          Sex        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    29.503186    33.281086     0.355997     0.498854
# std     378.020061    12.905241    51.741500     0.478997     1.041658
# min       1.000000     0.170000     0.000000     0.000000     0.000000
# 25%     328.000000    22.000000     7.895800     0.000000     0.000000
# 50%     655.000000    28.000000    14.454200     0.000000     0.000000
# 75%     982.000000    35.000000    31.275000     1.000000     1.000000
# max    1309.000000    80.000000   512.329200     1.000000     8.000000
#
#              Parch       Pclass     Embarked     2urvived
# count  1309.000000  1309.000000  1307.000000  1309.000000
# mean      0.385027     2.294882     1.492731     0.261268
# std       0.865560     0.837836     0.814626     0.439494
# min       0.000000     1.000000     0.000000     0.000000
# ...

# %%
df.corr()
# Out:
#              Passengerid       Age      Fare       Sex     sibsp     Parch  \
# Passengerid     1.000000  0.025799  0.031128 -0.013406 -0.055224  0.008942
# Age             0.025799  1.000000  0.178182 -0.053663 -0.189972 -0.125851
# Fare            0.031128  0.178182  1.000000  0.185681  0.160349  0.221635
# Sex            -0.013406 -0.053663  0.185681  1.000000  0.109609  0.213125
# sibsp          -0.055224 -0.189972  0.160349  0.109609  1.000000  0.373587
# Parch           0.008942 -0.125851  0.221635  0.213125  0.373587  1.000000
# Pclass         -0.038354 -0.377908 -0.558683 -0.124617  0.060832  0.018322
# Embarked       -0.051518 -0.065125 -0.239212 -0.099408  0.066055  0.045216
# 2urvived       -0.331493 -0.055862  0.173786  0.404020 -0.014375  0.054908
#
#                Pclass  Embarked  2urvived
# Passengerid -0.038354 -0.051518 -0.331493
# Age         -0.377908 -0.065125 -0.055862
# Fare        -0.558683 -0.239212  0.173786
# Sex         -0.124617 -0.099408  0.404020
# ...

# %%
df.head()
# Out:
#    Passengerid   Age     Fare  Sex  sibsp  Parch  Pclass  Embarked  2urvived
# 0            1  22.0   7.2500    0      1      0       3       2.0         0
# 1            2  38.0  71.2833    1      1      0       1       0.0         1
# 2            3  26.0   7.9250    1      0      0       3       2.0         1
# 3            4  35.0  53.1000    1      1      0       1       2.0         1
# 4            5  35.0   8.0500    0      0      0       3       2.0         0

# %%
#categorical data
df[['Age','Fare','Pclass','Embarked','Pclass','Parch']]
# Out:
#        Age      Fare  Pclass  Embarked  Pclass  Parch
# 0     22.0    7.2500       3       2.0       3      0
# 1     38.0   71.2833       1       0.0       1      0
# 2     26.0    7.9250       3       2.0       3      0
# 3     35.0   53.1000       1       2.0       1      0
# 4     35.0    8.0500       3       2.0       3      0
# ...    ...       ...     ...       ...     ...    ...
# 1304  28.0    8.0500       3       2.0       3      0
# 1305  39.0  108.9000       1       0.0       1      0
# 1306  38.5    7.2500       3       2.0       3      0
# 1307  28.0    8.0500       3       2.0       3      0
# 1308  28.0   22.3583       3       0.0       3      1
#
# [1309 rows x 6 columns]

# %%
import seaborn as sns

# %%
sns.countplot(df,x='2urvived')
df['2urvived'].value_counts()
# Out:
# 2urvived
# 0    967
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(df,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df,x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# Pie Chart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# 2.Numberical Data
# Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=50) #bins are used for creating intervals in the x axis
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  10.,   8.,   4.,  15.,  25.,  20.,
#          71.,  24.,  85.,  74.,  35.,  61., 298.,  72.,  47.,  25.,  41.,
#          33.,  23.,  39.,  14.,  27.,  10.,  29.,  28.,   9.,  23.,   6.,
#          14.,  13.,   5.,   9.,   8.,  10.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# Dist Plot (Improved version of Histogram)

# %%
sns.displot(df,x='Age',kind='kde')

# %%
sns.displot(df,x='Age')

# %%
sns.displot(df,x='Age',kde=True)
#Also used for skewness

# %% [markdown]
# Box Plot

# %%
sns.boxplot(df,x='Fare')
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(df,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
#This is generally used when data has noise/outliers and we want to ingnore them.

# %%
#we can use pandas function skew to get the skewness for the data
df['Fare'].skew()
#if its 0 its perfectly skewed
#if its +ve its right skewed
#if its -ve its left skewed
# Out:
# np.float64(4.3695095504693855)
